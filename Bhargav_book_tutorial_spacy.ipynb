# %%
pwd
# Out:
# '/home/jmjamison/work/JoyceWang/learnTextMining'

# %%
import plac
import random
from pathlib import Path
import spacy
nlp = spacy.load('en')
# also
import en_core_web_sm
nlp = en_core_web_sm.load()

from spacy.lang.en.stop_words import STOP_WORDS

print(STOP_WORDS)   #  spacy default stop_words
# Out:
# {'six', 'seeming', 'may', 'doing', 'fifteen', 'did', 'no', 'three', 'to', 'hundred', 'down', 'a', 'becomes', 'became', 'two', 'nor', 'whence', 'about', 'latterly', 'among', 'himself', 'my', 'not', 'that', 'get', 'serious', 'until', 'whenever', 'wherever', 'ourselves', 'ca', 'name', 'beside', 'it', 'nine', 'everyone', 'formerly', 'off', 'as', 'neither', 'thereby', 'they', 'itself', 'namely', 'below', 'around', 'whom', 'an', 're', 'thereafter', 'thru', 'yourselves', 'each', 'something', 'except', 'twenty', 'beforehand', 'me', 'also', 'he', 'themselves', 'used', 'than', 'thence', 'empty', 'on', 'him', 'anyhow', 'anything', 'up', 'show', 'either', 'still', 'afterwards', 'without', 'once', 'therein', 'part', 'bottom', 'could', 'which', 'his', 'one', 'least', 'those', 'none', 'i', 'whereupon', 'never', 'everything', 'becoming', 'seem', 'go', 'hence', 'sometimes', 'herself', 'always', 'along', 'further', 'next', 'mine', 'nowhere', 'say', 'meanwhile', 'this', 'regarding', 'throughout', 'less', 'such', 'must', 'after', 'at', 'before', 'last', 'quite', 'elsewhere', 'see', 'then', 'often', 'was', 'cannot', 'onto', 'some', 'your', 'can', 'during', 'yourself', 'others', 'few', 'were', 'do', 'forty', 'many', 'into', 'hers', 'because', 'between', 'done', 'both', 'else', 'over', 'therefore', 'any', 'every', 'toward', 'via', 'keep', 'five', 'are', 'same', 'using', 'above', 'only', 'in', 'and', 'due', 'please', 'our', 'third', 'all', 'but', 'there', 'together', 'will', 'anywhere', 'even', 'thereupon', 'whoever', 'whole', 'wherein', 'under', 'herein', 'indeed', 'anyway', 'full', 'give', 'these', 'we', 'back', 'although', 'perhaps', 'out', 'own', 'against', 'amongst', 'fifty', 'how', 'whether', 'former', 'hereafter', 'otherwise', 'side', 'whereafter', 'here', 'nevertheless', 'mostly', 'various', 'alone', 'across', 'am', 'however', 'sixty', 'anyone', 'been', 'through', 'front', 'towards', 'have', 'hereby', 'she', 'yet', 'might', 'nobody', 'beyond', 'for', 'where', 'would', 'top', 'ever', 'since', 'another', 'really', 'its', 'four', 'made', 'now', 'seemed', 'per', 'her', 'them', 'put', 'take', 'while', 'if', 'us', 'yours', 'noone', 'enough', 'should', 'eleven', 'whither', 'is', 'whereby', 'whose', 'myself', 'eight', 'though', 'just', 'be', 'rather', 'ours', 'seems', 'very', 'move', 'call', 'upon', 'hereupon', 'somewhere', 'why', 'much', 'somehow', 'within', 'nothing', 'of', 'does', 'latter', 'thus', 'whereas', 'you', 'or', 'with', 'moreover', 'by', 'from', 'become', 'when', 'several', 'make', 'first', 'behind', 'more', 'sometime', 'had', 'most', 'who', 'well', 'other', 'already', 'their', 'amount', 'what', 'again', 'besides', 'being', 'whatever', 'twelve', 'everywhere', 'so', 'someone', 'ten', 'unless', 'too', 'has', 'the', 'almost'}

# %%
# Python 3: Unicode default
# Python 2: enclose strings using u
doc = nlp('This is a sentance.')
doc
# Out:
# This is a sentance.

# %%
for token in doc:
    print((token.text, token.pos_))
# Out:
# ('This', 'DET')
# ('is', 'VERB')
# ('a', 'DET')
# ('sentance', 'NOUN')
# ('.', 'PUNCT')

# %%
# named entity recognition, page 47
doc2 = nlp('Microsoft has offices all over Europe.')

for ent in doc2.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
for token in doc2:
    print((token.text, token.pos_))
# Out:
# Microsoft 0 9 ORG
# Europe 31 37 LOC
# ('Microsoft', 'PROPN')
# ('has', 'VERB')
# ('offices', 'NOUN')
# ('all', 'ADV')
# ('over', 'ADP')
# ('Europe', 'PROPN')
# ('.', 'PUNCT')

# %%
# jabberwalky poem from alice in wonderland
docJabberwalky =  nlp(u'Twas brillig, and the slithy toves Did gyre and gimble in the wabe: All mimsy were the borogoves, And the mome raths outgrabe. “Beware the Jabberwock, my son! The jaws that bite, the claws that catch! Beware the Jubjub bird, and shun The frumious Bandersnatch!” He took his vorpal sword in hand; Long time the manxome foe he sought— So rested he by the Tumtum tree And stood awhile in thought. And, as in uffish thought he stood, The Jabberwock, with eyes of flame, Came whiffling through the tulgey wood, And burbled as it came! One, two! One, two! And through and through The vorpal blade went snicker-snack! He left it dead, and with its head He went galumphing back. “And hast thou slain the Jabberwock? Come to my arms, my beamish boy! O frabjous day! Callooh! Callay!” He chortled in his joy. ’Twas brillig, and the slithy toves Did gyre and gimble in the wabe: All mimsy were the borogoves, And the mome raths outgrabe.')

# %%
for token in docJabberwalky:
    print((token.text, token.pos_))
# Out:
# ('Twas', 'VERB')
# ('brillig', 'NOUN')
# (',', 'PUNCT')
# ('and', 'CCONJ')
# ('the', 'DET')
# ('slithy', 'ADJ')
# ('toves', 'NOUN')
# ('Did', 'VERB')
# ('gyre', 'NOUN')
# ('and', 'CCONJ')
# ('gimble', 'ADJ')
# ('in', 'ADP')
# ('the', 'DET')
# ('wabe', 'NOUN')
# (':', 'PUNCT')
# ('All', 'DET')
# ('mimsy', 'ADJ')
# ('were', 'VERB')
# ('the', 'DET')
# ('borogoves', 'NOUN')
# (',', 'PUNCT')
# ('And', 'CCONJ')
# ('the', 'DET')
# ('mome', 'ADJ')
# ('raths', 'NOUN')
# ('outgrabe', 'NOUN')
# ('.', 'PUNCT')
# ('“', 'PUNCT')
# ('Beware', 'VERB')
# ('the', 'DET')
# ('Jabberwock', 'PROPN')
# (',', 'PUNCT')
# ('my', 'ADJ')
# ('son', 'NOUN')
# ('!', 'PUNCT')
# ('The', 'DET')
# ('jaws', 'NOUN')
# ('that', 'DET')
# ('bite', 'VERB')
# (',', 'PUNCT')
# ('the', 'DET')
# ('claws', 'NOUN')
# ('that', 'ADJ')
# ('catch', 'VERB')
# ('!', 'PUNCT')
# ('Beware', 'VERB')
# ('the', 'DET')
# ('Jubjub', 'PROPN')
# ('bird', 'NOUN')
# (',', 'PUNCT')
# ('and', 'CCONJ')
# ('shun', 'VERB')
# ('The', 'DET')
# ('frumious', 'ADJ')
# ('Bandersnatch', 'PROPN')
# ('!', 'PUNCT')
# ('”', 'PUNCT')
# ('He', 'PRON')
# ('took', 'VERB')
# ('his', 'ADJ')
# ('vorpal', 'ADJ')
# ('sword', 'NOUN')
# ('in', 'ADP')
# ('hand', 'NOUN')
# (';', 'PUNCT')
# ('Long', 'ADJ')
# ('time', 'NOUN')
# ('the', 'DET')
# ('manxome', 'NOUN')
# ('foe', 'NOUN')
# ('he', 'PRON')
# ('sought—', 'VERB')
# ('So', 'ADV')
# ('rested', 'VERB')
# ('he', 'PRON')
# ('by', 'ADP')
# ('the', 'DET')
# ('Tumtum', 'PROPN')
# ('tree', 'NOUN')
# ('And', 'CCONJ')
# ('stood', 'VERB')
# ('awhile', 'ADV')
# ('in', 'ADP')
# ('thought', 'NOUN')
# ('.', 'PUNCT')
# ('And', 'CCONJ')
# (',', 'PUNCT')
# ('as', 'ADP')
# ('in', 'ADP')
# ('uffish', 'ADJ')
# ('thought', 'NOUN')
# ('he', 'PRON')
# ('stood', 'VERB')
# (',', 'PUNCT')
# ('The', 'DET')
# ('Jabberwock', 'PROPN')
# (',', 'PUNCT')
# ('with', 'ADP')
# ('eyes', 'NOUN')
# ('of', 'ADP')
# ('flame', 'NOUN')
# (',', 'PUNCT')
# ('Came', 'VERB')
# ('whiffling', 'VERB')
# ('through', 'ADP')
# ('the', 'DET')
# ('tulgey', 'ADJ')
# ('wood', 'NOUN')
# (',', 'PUNCT')
# ('And', 'CCONJ')
# ('burbled', 'VERB')
# ('as', 'ADP')
# ('it', 'PRON')
# ('came', 'VERB')
# ('!', 'PUNCT')
# ('One', 'NUM')
# (',', 'PUNCT')
# ('two', 'NUM')
# ('!', 'PUNCT')
# ('One', 'NUM')
# (',', 'PUNCT')
# ('two', 'NUM')
# ('!', 'PUNCT')
# ('And', 'CCONJ')
# ('through', 'ADP')
# ('and', 'CCONJ')
# ('through', 'ADP')
# ('The', 'DET')
# ('vorpal', 'ADJ')
# ('blade', 'NOUN')
# ('went', 'VERB')
# ('snicker', 'NOUN')
# ('-', 'PUNCT')
# ('snack', 'NOUN')
# ('!', 'PUNCT')
# ('He', 'PRON')
# ('left', 'VERB')
# ('it', 'PRON')
# ('dead', 'ADJ')
# (',', 'PUNCT')
# ('and', 'CCONJ')
# ('with', 'ADP')
# ('its', 'ADJ')
# ('head', 'NOUN')
# ('He', 'PRON')
# ('went', 'VERB')
# ('galumphing', 'VERB')
# ('back', 'ADV')
# ('.', 'PUNCT')
# ('“', 'PUNCT')
# ('And', 'CCONJ')
# ('hast', 'VERB')
# ('thou', 'VERB')
# ('slain', 'VERB')
# ('the', 'DET')
# ('Jabberwock', 'PROPN')
# ('?', 'PUNCT')
# ('Come', 'VERB')
# ('to', 'ADP')
# ('my', 'ADJ')
# ('arms', 'NOUN')
# (',', 'PUNCT')
# ('my', 'ADJ')
# ('beamish', 'NOUN')
# ('boy', 'NOUN')
# ('!', 'PUNCT')
# ('O', 'INTJ')
# ('frabjous', 'ADJ')
# ('day', 'NOUN')
# ('!', 'PUNCT')
# ('Callooh', 'PROPN')
# ('!', 'PUNCT')
# ('Callay', 'NOUN')
# ('!', 'PUNCT')
# ('”', 'PUNCT')
# ('He', 'PRON')
# ('chortled', 'VERB')
# ('in', 'ADP')
# ('his', 'ADJ')
# ('joy', 'NOUN')
# ('.', 'PUNCT')
# ('’Twas', 'ADJ')
# ('brillig', 'NOUN')
# (',', 'PUNCT')
# ('and', 'CCONJ')
# ('the', 'DET')
# ('slithy', 'ADJ')
# ('toves', 'NOUN')
# ('Did', 'VERB')
# ('gyre', 'NOUN')
# ('and', 'CCONJ')
# ('gimble', 'ADJ')
# ('in', 'ADP')
# ('the', 'DET')
# ('wabe', 'NOUN')
# (':', 'PUNCT')
# ('All', 'DET')
# ('mimsy', 'ADJ')
# ('were', 'VERB')
# ('the', 'DET')
# ('borogoves', 'NOUN')
# (',', 'PUNCT')
# ('And', 'CCONJ')
# ('the', 'DET')
# ('mome', 'ADJ')
# ('raths', 'NOUN')
# ('outgrabe', 'NOUN')
# ('.', 'PUNCT')

# %%
# example from Bargav book, page 50 
sentence = []  # make an array
for w in docJabberwalky:
    # if it's not a stop word or punctuation mark, add it to our article
    if w.text != 'n' and not w.is_stop and not w.is_punct and not w.like_num:
        # we add the lematized version the the word
        sentence.append(w.lemma_)
print(sentence)
# Out:
# ['twa', 'brillig', 'slithy', 'tof', 'do', 'gyre', 'gimble', 'wabe', 'all', 'mimsy', 'borogof', 'and', 'mome', 'rath', 'outgrabe', 'beware', 'jabberwock', 'son', 'the', 'jaw', 'bite', 'claws', 'catch', 'beware', 'jubjub', 'bird', 'shun', 'the', 'frumious', 'bandersnatch', '-PRON-', 'take', 'vorpal', 'sword', 'hand', 'long', 'time', 'manxome', 'foe', 'sought—', 'so', 'rest', 'tumtum', 'tree', 'and', 'stand', 'awhile', 'thought', 'and', 'uffish', 'thought', 'stand', 'the', 'jabberwock', 'eye', 'flame', 'come', 'whiffl', 'tulgey', 'wood', 'and', 'burble', 'come', 'one', 'one', 'and', 'the', 'vorpal', 'blade', 'go', 'snicker', 'snack', '-PRON-', 'leave', 'dead', 'head', '-PRON-', 'go', 'galumph', 'and', 'hast', 'thou', 'slay', 'jabberwock', 'come', 'arm', 'beamish', 'boy', 'o', 'frabjous', 'day', 'callooh', 'callay', '-PRON-', 'chortle', 'joy', '’twas', 'brillig', 'slithy', 'tof', 'do', 'gyre', 'gimble', 'wabe', 'all', 'mimsy', 'borogof', 'and', 'mome', 'rath', 'outgrabe']

# %%
# pos Part-Of-Speech tagging
# Bhargav book, page 73
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
text = nltk.word_tokenize("And now for something completely different")
nltk.pos_tag(text)
# Out:
# [nltk_data] Downloading package punkt to /home/jmjamison/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jmjamison/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %%
# apply same to jabberwalky
jText = nltk.word_tokenize(str(docJabberwalky))
nltk.pos_tag(jText)
# Out:
# [('Twas', 'NNP'),
#  ('brillig', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('slithy', 'JJ'),
#  ('toves', 'NNS'),
#  ('Did', 'NNP'),
#  ('gyre', 'NN'),
#  ('and', 'CC'),
#  ('gimble', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('wabe', 'NN'),
#  (':', ':'),
#  ('All', 'DT'),
#  ('mimsy', 'NNS'),
#  ('were', 'VBD'),
#  ('the', 'DT'),
#  ('borogoves', 'NNS'),
#  (',', ','),
#  ('And', 'CC'),
#  ('the', 'DT'),
#  ('mome', 'JJ'),
#  ('raths', 'NNS'),
#  ('outgrabe', 'RB'),
#  ('.', '.'),
#  ('“', 'CC'),
#  ('Beware', 'NNP'),
#  ('the', 'DT'),
#  ('Jabberwock', 'NNP'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('son', 'NN'),
#  ('!', '.'),
#  ('The', 'DT'),
#  ('jaws', 'NN'),
#  ('that', 'WDT'),
#  ('bite', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('claws', 'NN'),
#  ('that', 'WDT'),
#  ('catch', 'NN'),
#  ('!', '.'),
#  ('Beware', 'NNP'),
#  ('the', 'DT'),
#  ('Jubjub', 'NNP'),
#  ('bird', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('shun', 'VBD'),
#  ('The', 'DT'),
#  ('frumious', 'JJ'),
#  ('Bandersnatch', 'NN'),
#  ('!', '.'),
#  ('”', 'NN'),
#  ('He', 'PRP'),
#  ('took', 'VBD'),
#  ('his', 'PRP$'),
#  ('vorpal', 'JJ'),
#  ('sword', 'NN'),
#  ('in', 'IN'),
#  ('hand', 'NN'),
#  (';', ':'),
#  ('Long', 'NNP'),
#  ('time', 'NN'),
#  ('the', 'DT'),
#  ('manxome', 'NN'),
#  ('foe', 'NN'),
#  ('he', 'PRP'),
#  ('sought—', 'VBZ'),
#  ('So', 'RB'),
#  ('rested', 'VBN'),
#  ('he', 'PRP'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('Tumtum', 'NNP'),
#  ('tree', 'NN'),
#  ('And', 'CC'),
#  ('stood', 'VBD'),
#  ('awhile', 'NN'),
#  ('in', 'IN'),
#  ('thought', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  (',', ','),
#  ('as', 'IN'),
#  ('in', 'IN'),
#  ('uffish', 'JJ'),
#  ('thought', 'NN'),
#  ('he', 'PRP'),
#  ('stood', 'VBD'),
#  (',', ','),
#  ('The', 'DT'),
#  ('Jabberwock', 'NNP'),
#  (',', ','),
#  ('with', 'IN'),
#  ('eyes', 'NNS'),
#  ('of', 'IN'),
#  ('flame', 'NN'),
#  (',', ','),
#  ('Came', 'NNP'),
#  ('whiffling', 'VBG'),
#  ('through', 'IN'),
#  ('the', 'DT'),
#  ('tulgey', 'NN'),
#  ('wood', 'NN'),
#  (',', ','),
#  ('And', 'CC'),
#  ('burbled', 'VBD'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('came', 'VBD'),
#  ('!', '.'),
#  ('One', 'CD'),
#  (',', ','),
#  ('two', 'CD'),
#  ('!', '.'),
#  ('One', 'CD'),
#  (',', ','),
#  ('two', 'CD'),
#  ('!', '.'),
#  ('And', 'CC'),
#  ('through', 'IN'),
#  ('and', 'CC'),
#  ('through', 'IN'),
#  ('The', 'DT'),
#  ('vorpal', 'JJ'),
#  ('blade', 'NN'),
#  ('went', 'VBD'),
#  ('snicker-snack', 'NN'),
#  ('!', '.'),
#  ('He', 'PRP'),
#  ('left', 'VBD'),
#  ('it', 'PRP'),
#  ('dead', 'JJ'),
#  (',', ','),
#  ('and', 'CC'),
#  ('with', 'IN'),
#  ('its', 'PRP$'),
#  ('head', 'NN'),
#  ('He', 'PRP'),
#  ('went', 'VBD'),
#  ('galumphing', 'VBG'),
#  ('back', 'RB'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('And', 'CC'),
#  ('hast', 'NN'),
#  ('thou', 'NN'),
#  ('slain', 'VBP'),
#  ('the', 'DT'),
#  ('Jabberwock', 'NNP'),
#  ('?', '.'),
#  ('Come', 'NNP'),
#  ('to', 'TO'),
#  ('my', 'PRP$'),
#  ('arms', 'NNS'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('beamish', 'JJ'),
#  ('boy', 'NN'),
#  ('!', '.'),
#  ('O', 'NNP'),
#  ('frabjous', 'JJ'),
#  ('day', 'NN'),
#  ('!', '.'),
#  ('Callooh', 'NN'),
#  ('!', '.'),
#  ('Callay', 'NN'),
#  ('!', '.'),
#  ('”', 'NN'),
#  ('He', 'PRP'),
#  ('chortled', 'VBD'),
#  ('in', 'IN'),
#  ('his', 'PRP$'),
#  ('joy', 'NN'),
#  ('.', '.'),
#  ('’', 'NN'),
#  ('Twas', 'NNP'),
#  ('brillig', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('slithy', 'JJ'),
#  ('toves', 'NNS'),
#  ('Did', 'NNP'),
#  ('gyre', 'NN'),
#  ('and', 'CC'),
#  ('gimble', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('wabe', 'NN'),
#  (':', ':'),
#  ('All', 'DT'),
#  ('mimsy', 'NNS'),
#  ('were', 'VBD'),
#  ('the', 'DT'),
#  ('borogoves', 'NNS'),
#  (',', ','),
#  ('And', 'CC'),
#  ('the', 'DT'),
#  ('mome', 'JJ'),
#  ('raths', 'NNS'),
#  ('outgrabe', 'RB'),
#  ('.', '.')]
